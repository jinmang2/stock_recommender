# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pickle
with open('raw_data_20181008.pickle', 'rb') as handle:
    raw_data = pickle.load(handle)

# %%
import glob
import os.path
files = glob.glob('./20181107_result/*.xlsx')
for x in files:
    if not os.path.isdir(x):
        print (x)
        x2 = x.replace('.xlsx', '.csv')
        print ('==> ' + x2)
        os.rename(x, x2)
# Out:
# ./20181107_result\Y_AK홀딩스.xlsx
# ==> ./20181107_result\Y_AK홀딩스.csv
# ./20181107_result\Y_BNK금융지주.xlsx
# ==> ./20181107_result\Y_BNK금융지주.csv
# ./20181107_result\Y_CJ CGV.xlsx
# ==> ./20181107_result\Y_CJ CGV.csv
# ./20181107_result\Y_CJ.xlsx
# ==> ./20181107_result\Y_CJ.csv
# ./20181107_result\Y_CJ대한통운.xlsx
# ==> ./20181107_result\Y_CJ대한통운.csv
# ./20181107_result\Y_CJ제일제당.xlsx
# ==> ./20181107_result\Y_CJ제일제당.csv
# ./20181107_result\Y_DB손해보험.xlsx
# ==> ./20181107_result\Y_DB손해보험.csv
# ./20181107_result\Y_DB하이텍.xlsx
# ==> ./20181107_result\Y_DB하이텍.csv
# ./20181107_result\Y_GKL.xlsx
# ==> ./20181107_result\Y_GKL.csv
# ./20181107_result\Y_GS.xlsx
# ==> ./20181107_result\Y_GS.csv
# ./20181107_result\Y_GS건설.xlsx
# ==> ./20181107_result\Y_GS건설.csv
# ./20181107_result\Y_GS리테일.xlsx
# ==> ./20181107_result\Y_GS리테일.csv
# ./20181107_result\Y_HDC.xlsx
# ==> ./20181107_result\Y_HDC.csv
# ./20181107_result\Y_JW중외제약.xlsx
# ==> ./20181107_result\Y_JW중외제약.csv
# ./20181107_result\Y_JW홀딩스.xlsx
# ...

# %%
result_dict = {}
for stock in raw_data.keys():
    try:
        result_dict[stock] = pd.read_csv('./20181107_result/Y_{}.csv'.format(stock))
    except:
        pass

# %%
result_dict.keys()
# Out:
# dict_keys([])

# %%
import csv
rownum = 0
data = []
with open("./20181107_result/Y_AK홀딩스.csv", "r", encoding = "utf-8") as p_file:
    csv_data = csv.reader(p_file)
    for row in csv_data:
        if rownum == 0:
            header = row
        else:
            data.append(row)
        rownum += 1
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-62815ef50740> in <module>()
#       4 with open("./20181107_result/Y_AK홀딩스.csv", "r", encoding = "utf-8") as p_file:
#       5     csv_data = csv.reader(p_file)
# ----> 6     for row in csv_data:
#       7         if rownum == 0:
#       8             header = row
#
# ~\Anaconda3\envs\ds\lib\codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcf in position 16: invalid continuation byte
