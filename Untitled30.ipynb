# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import pickle
with open('raw_data_20181008.pickle', 'rb') as handle:
    raw_data = pickle.load(handle)
    
copy_keys = list(raw_data.keys())
for stock in copy_keys:
    if len(raw_data[stock].loc[:'2013-01-01']) < 1:
        del raw_data[stock]
del copy_keys

# stock에서 Volume==0인 index, stock에서 제외
for key, df in raw_data.items():
    raw_data[key] = df.drop(df.index[np.where(df.Volume==0)[0]], axis=0)
    del df['Adj Close']
    df.Volume = df.Volume / 1e7

# %%
for key, df in raw_data.items():
    print(key)
    for i in range(1, 11):
        df['returnsCloseNext{}'.format(i)] = np.log(df['Close'].shift(-1*i) / df['Open']) - np.log(df['Close'] / df['Open'].shift(i))

    # Moving Average
    df['close_ma_50'] = df.Close.rolling(50).mean()

    # Return of Change
    df['roc_1'] = df.Close.pct_change(periods=1)
    df['roc_2'] = df.Close.pct_change(periods=2)

    # RSI
    U = np.where(df.Close.diff(1) > 0, df.Close.diff(1), 0)
    D = np.where(df.Close.diff(1) < 0, df.Close.diff(1)*(-1), 0)
    m_N = 10
    AU = pd.DataFrame(U).rolling(window=m_N, min_periods=m_N).mean()
    AD = pd.DataFrame(D).rolling(window=m_N, min_periods=m_N).mean()
    RSI = AU.div(AD+AU)*100
    df['rsi_10'] = RSI.values

    # CV
    df['his_vol_10'] = df.Close.rolling(10).std() / df.Close.rolling(10).mean()

    # William%R
    n = 14
    W_R = -100 * ((df.High.rolling(n).max() - df.Close) / 
       (df.High.rolling(n).max() - df.Low.rolling(n).min()))
    df['w_r'] = W_R

    # Stochastic Oscillator
    percent_K = 100 * ((df.Close - df.Low.rolling(n).min()) / 
       (df.High.rolling(n).max() - df.Low.rolling(n).min()))
    sto_slowD = percent_K.rolling(3).mean().rolling(3).mean()
    df['sto_slowD'] = sto_slowD

    # Commodity Channel Index
    TP = (df.Close + df.Low + df.High) / 3
    window = 20
    dataX = []
    for i in range(len(TP) - window+1):
        a = TP.values[i:(i+window)]
        dataX.append(a)
    dataMean = [i.mean() for i in dataX]
    AVEDEV = [abs(x - mean).mean() for x, mean 
              in zip(dataX, dataMean)]
    for i in range(window-1):
        AVEDEV.insert(0,np.nan)
    AVEDEV = pd.Series(AVEDEV, index = TP.index)
    CCI = (TP - TP.rolling(20).mean()) / (0.015 * AVEDEV)
    df['cci'] = CCI

    # Disparity Index
    DI5 = 100 * ((df.Close - df.Close.rolling(5).mean()) / 
                df.Close.rolling(5).mean())
    DI10 = 100 * ((df.Close - df.Close.rolling(10).mean()) / 
                df.Close.rolling(10).mean())
    df['di5'] = DI5
    df['di10'] = DI10

    # Volume Prce Trend
    VPT = pd.Series(index=df.index)
    VPT.iloc[0] = 0
    for n in 
    range(1, len(VPT)):
        VPT.iloc[n] = VPT.iloc[n-1] + ((df.Close.diff(1) / df.Close) * df.Volume).iloc[n]
    df['vpt'] = VPT
# Out:
# AK홀딩스
# BNK금융지주
# CJ
# CJ CGV
# CJ대한통운
# CJ제일제당
# DB손해보험
# DB하이텍
# GKL
# GS
# GS건설
# GS리테일
# HDC
# JW중외제약
# JW홀딩스
# KB금융
# KCC
# KT
# KT&G
# LF
# LG
# LG디스플레이
# LG상사
# LG생활건강
# LG유플러스
# LG이노텍
# LG전자
# LG하우시스
# LG화학
# LS
# LS산전
# NAVER
# NH투자증권
# OCI
# POSCO
# S&T모티브
# S-Oil
# SBS
# SK
# SKC
# SK네트웍스
# SK디스커버리
# SK이노베이션
# SK텔레콤
# SK하이닉스
# SPC삼립
# 강원랜드
# 고려아연
# 고려제강
# 금호석유
# 금호타이어
# 기아차
# 기업은행
# 남양유업
# 남해화학
# 넥센타이어
# 녹십자
# 녹십자홀딩스
# 농심
# 대교
# 대덕전자
# 대림산업
# 대상
# 대우건설
# 대우조선해양
# 대웅제약
# 대한유화
# 대한항공
# 동국제강
# 동서
# 동아쏘시오홀딩스
# 동양
# 동원F&B
# 동원시스템즈
# 두산
# 두산인프라코어
# 두산중공업
# 락앤락
# 롯데쇼핑
# 롯데정밀화학
# 롯데지주
# 롯데칠성
# 롯데케미칼
# 롯데푸드
# 롯데하이마트
# 메리츠종금증권
# 무학
# 미래에셋대우
# 보령제약
# 부광약품
# 빙그레
# 삼성SDI
# 삼성생명
# 삼성엔지니어링
# 삼성전기
# 삼성전자
# 삼성중공업
# 삼성증권
# 삼성카드
# 삼성화재
# 삼양사
# 삼양홀딩스
# 세방전지
# 세아베스틸
# 세아제강
# 셀트리온
# 신세계
# 신한지주
# 쌍용양회
# 쌍용차
# 아모레G
# 아모레퍼시픽
# 아이에스동서
# 에스엘
# 에스원
# 엔씨소프트
# 영원무역
# 영진약품
# 영풍
# 오뚜기
# 오리온홀딩스
# 우리은행
# 유니드
# 유한양행
# 이마트
# 일양약품
# 일진머티리얼즈
# 제일기획
# 카카오
# 코오롱인더
# 코웨이
# 태광산업
# 팜스코
# 팬오션
# 포스코대우
# 풍산
# 하나금융지주
# 하이트진로
# 한국가스공사
# 한국금융지주
# 한국단자
# 한국쉘석유
# 한국전력
# 한국콜마
# 한국타이어
# 한국타이어월드와이드
# 한국항공우주
# 한라홀딩스
# 한미사이언스
# 한미약품
# 한샘
# 한섬
# 한세실업
# 한솔케미칼
# 한온시스템
# 한올바이오파마
# 한일시멘트
# 한전KPS
# 한전기술
# 한진중공업
# 한화
# 한화생명
# 한화에어로스페이스
# 한화케미칼
# 현대건설
# 현대그린푸드
# 현대글로비스
# 현대리바트
# 현대모비스
# 현대미포조선
# 현대백화점
# 현대엘리베이
# 현대위아
# 현대제철
# 현대중공업
# 현대차
# 현대해상
# 현대홈쇼핑
# 호텔신라
# 효성
# 후성
# 휴켐스

# %%
y_li = [col for col in raw_data['삼성전자'].columns if col.find('Next') != -1]
X_li = [col for col in raw_data['삼성전자'].columns if col.find('Next') == -1]

# %%
from xgboost import XGBRegressor
xgb_reg = XGBRegressor()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import time
from xgboost import XGBRegressor

# %%
for key, df in raw_data.items():
    raw_data[key] = df.dropna()

# %%
for key, df in raw_data.items():
    raw_data[key] = df.loc['2013-01-01':]

# %%
result = {}
start = time.time()
y = 'returnsCloseNext1'
for key, df in raw_data.items():
    semi_start = time.time()
    
    train_data = df.iloc[:int(0.8*len(df))][X_li].values
    train_label = df.iloc[:int(0.8*len(df))][y].values
    test_data = df.iloc[int(0.8*len(df)):][X_li].values
    test_label = df.iloc[int(0.8*len(df)):][y]
    xgb_reg = XGBRegressor()
    xgb_reg.fit(train_data, train_label)
    pred = pd.Series(xgb_reg.predict(test_data), index=test_label.index)
    rmse = metrics.mean_squared_error(test_label.values, pred.values) ** .5
    accuracy = metrics.accuracy_score(np.where(test_label.values>0, 1, 0), 
                       np.where(pred.values>0, 1, 0))
    result[key] = [rmse, accuracy, pred]
    
    semi_elapse = time.time() - semi_start
    print('Done :', key, '\n\t{:.4f} sec'.format(semi_elapse))
# Out:
# Done : AK홀딩스
# 	0.2962 sec
# Done : BNK금융지주
# 	0.1456 sec
# Done : CJ
# 	0.1765 sec
# Done : CJ CGV
# 	0.1676 sec
# Done : CJ대한통운
# 	0.1915 sec
# Done : CJ제일제당
# 	0.1656 sec
# Done : DB손해보험
# 	0.1905 sec
# Done : DB하이텍
# 	0.1905 sec
# Done : GKL
# 	0.1835 sec
# Done : GS
# 	0.1725 sec
# Done : GS건설
# 	0.1855 sec
# Done : GS리테일
# 	0.1416 sec
# Done : HDC
# 	0.1745 sec
# Done : JW중외제약
# 	0.1745 sec
# Done : JW홀딩스
# 	0.1845 sec
# Done : KB금융
# 	0.1715 sec
# Done : KCC
# 	0.1855 sec
# Done : KT
# 	0.1715 sec
# Done : KT&G
# 	0.1885 sec
# Done : LF
# 	0.1715 sec
# Done : LG
# 	0.1745 sec
# Done : LG디스플레이
# 	0.1765 sec
# Done : LG상사
# 	0.1765 sec
# Done : LG생활건강
# 	0.1735 sec
# Done : LG유플러스
# 	0.1745 sec
# Done : LG이노텍
# 	0.1725 sec
# Done : LG전자
# 	0.2005 sec
# Done : LG하우시스
# 	0.1825 sec
# Done : LG화학
# 	0.1826 sec
# Done : LS
# 	0.3750 sec
# Done : LS산전
# 	0.2105 sec
# Done : NAVER
# 	0.2014 sec
# Done : NH투자증권
# 	0.1985 sec
# Done : OCI
# 	0.1875 sec
# Done : POSCO
# 	0.1905 sec
# Done : S&T모티브
# 	0.1895 sec
# Done : S-Oil
# 	0.1905 sec
# Done : SBS
# 	0.1895 sec
# Done : SK
# 	0.1705 sec
# Done : SKC
# 	0.1795 sec
# Done : SK네트웍스
# 	0.2234 sec
# Done : SK디스커버리
# 	0.1636 sec
# Done : SK이노베이션
# 	0.1985 sec
# Done : SK텔레콤
# 	0.1955 sec
# Done : SK하이닉스
# 	0.1935 sec
# Done : SPC삼립
# 	0.1805 sec
# Done : 강원랜드
# 	0.2025 sec
# Done : 고려아연
# 	0.1975 sec
# Done : 고려제강
# 	0.1935 sec
# Done : 금호석유
# 	0.1755 sec
# Done : 금호타이어
# 	0.1726 sec
# Done : 기아차
# 	0.1685 sec
# Done : 기업은행
# 	0.1606 sec
# Done : 남양유업
# 	0.1985 sec
# Done : 남해화학
# 	0.1835 sec
# Done : 넥센타이어
# 	0.1895 sec
# Done : 녹십자
# 	0.1695 sec
# Done : 녹십자홀딩스
# 	0.1746 sec
# Done : 농심
# 	0.1666 sec
# Done : 대교
# 	0.1805 sec
# Done : 대덕전자
# 	0.2733 sec
# Done : 대림산업
# 	0.3281 sec
# Done : 대상
# 	0.1735 sec
# Done : 대우건설
# 	0.1925 sec
# Done : 대우조선해양
# 	0.1706 sec
# Done : 대웅제약
# 	0.1905 sec
# Done : 대한유화
# 	0.1795 sec
# Done : 대한항공
# 	0.1715 sec
# Done : 동국제강
# 	0.1746 sec
# Done : 동서
# 	0.1845 sec
# Done : 동아쏘시오홀딩스
# 	0.1656 sec
# Done : 동양
# 	0.2015 sec
# Done : 동원F&B
# 	0.1745 sec
# Done : 동원시스템즈
# 	0.1895 sec
# Done : 두산
# 	0.1945 sec
# Done : 두산인프라코어
# 	0.1865 sec
# Done : 두산중공업
# 	0.1845 sec
# Done : 락앤락
# 	0.1736 sec
# Done : 롯데쇼핑
# 	0.1865 sec
# Done : 롯데정밀화학
# 	0.1905 sec
# Done : 롯데지주
# 	0.1755 sec
# Done : 롯데칠성
# 	0.1975 sec
# Done : 롯데케미칼
# 	0.1736 sec
# Done : 롯데푸드
# 	0.1755 sec
# Done : 롯데하이마트
# 	0.1646 sec
# Done : 메리츠종금증권
# 	0.1865 sec
# Done : 무학
# 	0.1825 sec
# Done : 미래에셋대우
# 	0.1775 sec
# Done : 보령제약
# 	0.2104 sec
# Done : 부광약품
# 	0.2164 sec
# Done : 빙그레
# 	0.2184 sec
# Done : 삼성SDI
# 	0.2015 sec
# Done : 삼성생명
# 	0.1546 sec
# Done : 삼성엔지니어링
# 	0.1905 sec
# Done : 삼성전기
# 	0.2124 sec
# Done : 삼성전자
# 	0.1995 sec
# Done : 삼성중공업
# 	0.1745 sec
# Done : 삼성증권
# 	0.1795 sec
# Done : 삼성카드
# 	0.1636 sec
# Done : 삼성화재
# 	0.1636 sec
# Done : 삼양사
# 	0.1725 sec
# Done : 삼양홀딩스
# 	0.1785 sec
# Done : 세방전지
# 	0.1656 sec
# Done : 세아베스틸
# 	0.1845 sec
# Done : 세아제강
# 	0.1666 sec
# Done : 셀트리온
# 	0.1795 sec
# Done : 신세계
# 	0.1595 sec
# Done : 신한지주
# 	0.1725 sec
# Done : 쌍용양회
# 	0.1715 sec
# Done : 쌍용차
# 	0.1715 sec
# Done : 아모레G
# 	0.1736 sec
# Done : 아모레퍼시픽
# 	0.1705 sec
# Done : 아이에스동서
# 	0.1725 sec
# Done : 에스엘
# 	0.1695 sec
# Done : 에스원
# 	0.1686 sec
# Done : 엔씨소프트
# 	0.1835 sec
# Done : 영원무역
# 	0.1735 sec
# Done : 영진약품
# 	0.1745 sec
# Done : 영풍
# 	0.1755 sec
# Done : 오뚜기
# 	0.1785 sec
# Done : 오리온홀딩스
# 	0.1686 sec
# Done : 우리은행
# 	0.1706 sec
# Done : 유니드
# 	0.1645 sec
# Done : 유한양행
# 	0.1676 sec
# Done : 이마트
# 	0.1396 sec
# Done : 일양약품
# 	0.1785 sec
# Done : 일진머티리얼즈
# 	0.1486 sec
# Done : 제일기획
# 	0.1785 sec
# Done : 카카오
# 	0.1705 sec
# Done : 코오롱인더
# 	0.1795 sec
# Done : 코웨이
# 	0.1715 sec
# Done : 태광산업
# 	0.1796 sec
# Done : 팜스코
# 	0.1925 sec
# Done : 팬오션
# 	0.1995 sec
# Done : 포스코대우
# 	0.1745 sec
# Done : 풍산
# 	0.1705 sec
# Done : 하나금융지주
# 	0.1705 sec
# Done : 하이트진로
# 	0.1656 sec
# Done : 한국가스공사
# 	0.1736 sec
# Done : 한국금융지주
# 	0.1945 sec
# Done : 한국단자
# 	0.1715 sec
# Done : 한국쉘석유
# 	0.1686 sec
# Done : 한국전력
# 	0.1695 sec
# Done : 한국콜마
# 	0.1326 sec
# Done : 한국타이어
# 	0.1197 sec
# Done : 한국타이어월드와이드
# 	0.1706 sec
# Done : 한국항공우주
# 	0.1546 sec
# Done : 한라홀딩스
# 	0.1666 sec
# Done : 한미사이언스
# 	0.1715 sec
# Done : 한미약품
# 	0.1656 sec
# Done : 한샘
# 	0.1705 sec
# Done : 한섬
# 	0.1705 sec
# Done : 한세실업
# 	0.1885 sec
# Done : 한솔케미칼
# 	0.1786 sec
# Done : 한온시스템
# 	0.1855 sec
# Done : 한올바이오파마
# 	0.1806 sec
# Done : 한일시멘트
# 	0.1705 sec
# Done : 한전KPS
# 	0.1715 sec
# Done : 한전기술
# 	0.1845 sec
# Done : 한진중공업
# 	0.1725 sec
# Done : 한화
# 	0.1735 sec
# Done : 한화생명
# 	0.1616 sec
# Done : 한화에어로스페이스
# 	0.1815 sec
# Done : 한화케미칼
# 	0.1706 sec
# Done : 현대건설
# 	0.1875 sec
# Done : 현대그린푸드
# 	0.1575 sec
# Done : 현대글로비스
# 	0.1676 sec
# Done : 현대리바트
# 	0.1775 sec
# Done : 현대모비스
# 	0.1626 sec
# Done : 현대미포조선
# 	0.1686 sec
# Done : 현대백화점
# 	0.1786 sec
# Done : 현대엘리베이
# 	0.1845 sec
# Done : 현대위아
# 	0.1506 sec
# Done : 현대제철
# 	0.1735 sec
# Done : 현대중공업
# 	0.1746 sec
# Done : 현대차
# 	0.1636 sec
# Done : 현대해상
# 	0.1795 sec
# Done : 현대홈쇼핑
# 	0.1456 sec
# Done : 호텔신라
# 	0.1775 sec
# Done : 효성
# 	0.1666 sec
# Done : 후성
# 	0.1796 sec
# Done : 휴켐스
# 	0.1556 sec

# %%
for key, data in result.items():
    print(key, '\n\t RMSE:{:.3f}\tAccuracy:{:.4f}'.format(data[0], data[1]))
# Out:
# AK홀딩스
# 	 RMSE:0.021	Accuracy:0.7002
# BNK금융지주
# 	 RMSE:0.017	Accuracy:0.6620
# CJ
# 	 RMSE:0.020	Accuracy:0.7071
# CJ CGV
# 	 RMSE:0.025	Accuracy:0.7119
# CJ대한통운
# 	 RMSE:0.023	Accuracy:0.6619
# CJ제일제당
# 	 RMSE:0.017	Accuracy:0.6929
# DB손해보험
# 	 RMSE:0.021	Accuracy:0.7095
# DB하이텍
# 	 RMSE:0.031	Accuracy:0.6976
# GKL
# 	 RMSE:0.025	Accuracy:0.7071
# GS
# 	 RMSE:0.018	Accuracy:0.7071
# GS건설
# 	 RMSE:0.030	Accuracy:0.7143
# GS리테일
# 	 RMSE:0.030	Accuracy:0.7072
# HDC
# 	 RMSE:0.039	Accuracy:0.7005
# JW중외제약
# 	 RMSE:0.025	Accuracy:0.7024
# JW홀딩스
# 	 RMSE:0.030	Accuracy:0.7119
# KB금융
# 	 RMSE:0.021	Accuracy:0.6738
# KCC
# 	 RMSE:0.022	Accuracy:0.6905
# KT
# 	 RMSE:0.012	Accuracy:0.6905
# KT&G
# 	 RMSE:0.016	Accuracy:0.7000
# LF
# 	 RMSE:0.025	Accuracy:0.7000
# LG
# 	 RMSE:0.020	Accuracy:0.6738
# LG디스플레이
# 	 RMSE:0.027	Accuracy:0.6690
# LG상사
# 	 RMSE:0.024	Accuracy:0.7000
# LG생활건강
# 	 RMSE:0.028	Accuracy:0.6452
# LG유플러스
# 	 RMSE:0.026	Accuracy:0.6881
# LG이노텍
# 	 RMSE:0.033	Accuracy:0.6690
# LG전자
# 	 RMSE:0.027	Accuracy:0.7214
# LG하우시스
# 	 RMSE:0.019	Accuracy:0.6810
# LG화학
# 	 RMSE:0.023	Accuracy:0.7000
# LS
# 	 RMSE:0.026	Accuracy:0.7500
# LS산전
# 	 RMSE:0.027	Accuracy:0.7000
# NAVER
# 	 RMSE:0.020	Accuracy:0.6875
# NH투자증권
# 	 RMSE:0.025	Accuracy:0.6714
# OCI
# 	 RMSE:0.032	Accuracy:0.7190
# POSCO
# 	 RMSE:0.025	Accuracy:0.6714
# S&T모티브
# 	 RMSE:0.026	Accuracy:0.6905
# S-Oil
# 	 RMSE:0.027	Accuracy:0.6429
# SBS
# 	 RMSE:0.019	Accuracy:0.6952
# SK
# 	 RMSE:0.028	Accuracy:0.6048
# SKC
# 	 RMSE:0.024	Accuracy:0.6929
# SK네트웍스
# 	 RMSE:0.019	Accuracy:0.7000
# SK디스커버리
# 	 RMSE:0.021	Accuracy:0.6964
# SK이노베이션
# 	 RMSE:0.021	Accuracy:0.7024
# SK텔레콤
# 	 RMSE:0.016	Accuracy:0.7262
# SK하이닉스
# 	 RMSE:0.028	Accuracy:0.6238
# SPC삼립
# 	 RMSE:0.028	Accuracy:0.7024
# 강원랜드
# 	 RMSE:0.019	Accuracy:0.6833
# 고려아연
# 	 RMSE:0.019	Accuracy:0.6929
# 고려제강
# 	 RMSE:0.017	Accuracy:0.7000
# 금호석유
# 	 RMSE:0.028	Accuracy:0.6857
# 금호타이어
# 	 RMSE:0.062	Accuracy:0.7050
# 기아차
# 	 RMSE:0.018	Accuracy:0.6905
# 기업은행
# 	 RMSE:0.019	Accuracy:0.6167
# 남양유업
# 	 RMSE:0.016	Accuracy:0.6952
# 남해화학
# 	 RMSE:0.046	Accuracy:0.6897
# 넥센타이어
# 	 RMSE:0.016	Accuracy:0.6429
# 녹십자
# 	 RMSE:0.027	Accuracy:0.6524
# 녹십자홀딩스
# 	 RMSE:0.027	Accuracy:0.6859
# 농심
# 	 RMSE:0.018	Accuracy:0.6667
# 대교
# 	 RMSE:0.011	Accuracy:0.6571
# 대덕전자
# 	 RMSE:0.020	Accuracy:0.6976
# 대림산업
# 	 RMSE:0.022	Accuracy:0.7310
# 대상
# 	 RMSE:0.021	Accuracy:0.7167
# 대우건설
# 	 RMSE:0.043	Accuracy:0.6071
# 대우조선해양
# 	 RMSE:0.091	Accuracy:0.6555
# 대웅제약
# 	 RMSE:0.075	Accuracy:0.6190
# 대한유화
# 	 RMSE:0.032	Accuracy:0.6500
# 대한항공
# 	 RMSE:0.024	Accuracy:0.7264
# 동국제강
# 	 RMSE:0.034	Accuracy:0.7310
# 동서
# 	 RMSE:0.016	Accuracy:0.6690
# 동아쏘시오홀딩스
# 	 RMSE:0.024	Accuracy:0.7015
# 동양
# 	 RMSE:0.029	Accuracy:0.7146
# 동원F&B
# 	 RMSE:0.027	Accuracy:0.7071
# 동원시스템즈
# 	 RMSE:0.027	Accuracy:0.6562
# 두산
# 	 RMSE:0.023	Accuracy:0.6667
# 두산인프라코어
# 	 RMSE:0.031	Accuracy:0.7214
# 두산중공업
# 	 RMSE:0.046	Accuracy:0.6381
# 락앤락
# 	 RMSE:0.030	Accuracy:0.6779
# 롯데쇼핑
# 	 RMSE:0.034	Accuracy:0.6595
# 롯데정밀화학
# 	 RMSE:0.033	Accuracy:0.5452
# 롯데지주
# 	 RMSE:0.027	Accuracy:0.6763
# 롯데칠성
# 	 RMSE:0.019	Accuracy:0.6739
# 롯데케미칼
# 	 RMSE:0.027	Accuracy:0.6619
# 롯데푸드
# 	 RMSE:0.021	Accuracy:0.7002
# 롯데하이마트
# 	 RMSE:0.024	Accuracy:0.7500
# 메리츠종금증권
# 	 RMSE:0.024	Accuracy:0.7262
# 무학
# 	 RMSE:0.020	Accuracy:0.7143
# 미래에셋대우
# 	 RMSE:0.030	Accuracy:0.5929
# 보령제약
# 	 RMSE:0.026	Accuracy:0.7122
# 부광약품
# 	 RMSE:0.023	Accuracy:0.7000
# 빙그레
# 	 RMSE:0.017	Accuracy:0.6762
# 삼성SDI
# 	 RMSE:0.043	Accuracy:0.6143
# 삼성생명
# 	 RMSE:0.019	Accuracy:0.6741
# 삼성엔지니어링
# 	 RMSE:0.032	Accuracy:0.6890
# 삼성전기
# 	 RMSE:0.028	Accuracy:0.6595
# 삼성전자
# 	 RMSE:0.021	Accuracy:0.6253
# 삼성중공업
# 	 RMSE:0.038	Accuracy:0.6952
# 삼성증권
# 	 RMSE:0.020	Accuracy:0.6857
# 삼성카드
# 	 RMSE:0.016	Accuracy:0.6500
# 삼성화재
# 	 RMSE:0.017	Accuracy:0.6476
# 삼양사
# 	 RMSE:0.018	Accuracy:0.6884
# 삼양홀딩스
# 	 RMSE:0.029	Accuracy:0.6981
# 세방전지
# 	 RMSE:0.016	Accuracy:0.6667
# 세아베스틸
# 	 RMSE:0.023	Accuracy:0.7119
# 세아제강
# 	 RMSE:0.032	Accuracy:0.7332
# 셀트리온
# 	 RMSE:0.092	Accuracy:0.5707
# 신세계
# 	 RMSE:0.033	Accuracy:0.6643
# 신한지주
# 	 RMSE:0.017	Accuracy:0.6786
# 쌍용양회
# 	 RMSE:0.058	Accuracy:0.6019
# 쌍용차
# 	 RMSE:0.045	Accuracy:0.6570
# 아모레G
# 	 RMSE:0.028	Accuracy:0.7033
# 아모레퍼시픽
# 	 RMSE:0.025	Accuracy:0.6914
# 아이에스동서
# 	 RMSE:0.025	Accuracy:0.6905
# 에스엘
# 	 RMSE:0.028	Accuracy:0.7286
# 에스원
# 	 RMSE:0.019	Accuracy:0.6881
# 엔씨소프트
# 	 RMSE:0.036	Accuracy:0.6452
# 영원무역
# 	 RMSE:0.025	Accuracy:0.7167
# 영진약품
# 	 RMSE:0.037	Accuracy:0.7119
# 영풍
# 	 RMSE:0.021	Accuracy:0.6143
# 오뚜기
# 	 RMSE:0.028	Accuracy:0.6690
# 오리온홀딩스
# 	 RMSE:0.029	Accuracy:0.6860
# 우리은행
# 	 RMSE:0.026	Accuracy:0.6473
# 유니드
# 	 RMSE:0.019	Accuracy:0.7143
# 유한양행
# 	 RMSE:0.021	Accuracy:0.6976
# 이마트
# 	 RMSE:0.027	Accuracy:0.7155
# 일양약품
# 	 RMSE:0.024	Accuracy:0.7238
# 일진머티리얼즈
# 	 RMSE:0.073	Accuracy:0.5497
# 제일기획
# 	 RMSE:0.021	Accuracy:0.7033
# 카카오
# 	 RMSE:0.028	Accuracy:0.6929
# 코오롱인더
# 	 RMSE:0.023	Accuracy:0.7380
# 코웨이
# 	 RMSE:0.026	Accuracy:0.6571
# 태광산업
# 	 RMSE:0.026	Accuracy:0.6929
# 팜스코
# 	 RMSE:0.021	Accuracy:0.6833
# 팬오션
# 	 RMSE:0.033	Accuracy:0.6815
# 포스코대우
# 	 RMSE:0.029	Accuracy:0.7119
# 풍산
# 	 RMSE:0.027	Accuracy:0.6786
# 하나금융지주
# 	 RMSE:0.025	Accuracy:0.6929
# 하이트진로
# 	 RMSE:0.025	Accuracy:0.6595
# 한국가스공사
# 	 RMSE:0.022	Accuracy:0.7262
# 한국금융지주
# 	 RMSE:0.028	Accuracy:0.6643
# 한국단자
# 	 RMSE:0.019	Accuracy:0.6810
# 한국쉘석유
# 	 RMSE:0.010	Accuracy:0.6762
# 한국전력
# 	 RMSE:0.017	Accuracy:0.7119
# 한국콜마
# 	 RMSE:0.029	Accuracy:0.6893
# 한국타이어
# 	 RMSE:0.020	Accuracy:0.7128
# 한국타이어월드와이드
# 	 RMSE:0.016	Accuracy:0.6602
# 한국항공우주
# 	 RMSE:0.037	Accuracy:0.7006
# 한라홀딩스
# 	 RMSE:0.022	Accuracy:0.6591
# 한미사이언스
# 	 RMSE:0.033	Accuracy:0.6683
# 한미약품
# 	 RMSE:0.031	Accuracy:0.7059
# 한샘
# 	 RMSE:0.026	Accuracy:0.7167
# 한섬
# 	 RMSE:0.025	Accuracy:0.6905
# 한세실업
# 	 RMSE:0.030	Accuracy:0.6905
# 한솔케미칼
# 	 RMSE:0.022	Accuracy:0.6643
# 한온시스템
# 	 RMSE:0.028	Accuracy:0.6954
# 한올바이오파마
# 	 RMSE:0.047	Accuracy:0.7119
# 한일시멘트
# 	 RMSE:0.047	Accuracy:0.6836
# 한전KPS
# 	 RMSE:0.026	Accuracy:0.6952
# 한전기술
# 	 RMSE:0.040	Accuracy:0.7167
# 한진중공업
# 	 RMSE:0.031	Accuracy:0.6643
# 한화
# 	 RMSE:0.020	Accuracy:0.6738
# 한화생명
# 	 RMSE:0.021	Accuracy:0.6610
# 한화에어로스페이스
# 	 RMSE:0.029	Accuracy:0.7214
# 한화케미칼
# 	 RMSE:0.025	Accuracy:0.7310
# 현대건설
# 	 RMSE:0.039	Accuracy:0.6881
# 현대그린푸드
# 	 RMSE:0.017	Accuracy:0.6842
# 현대글로비스
# 	 RMSE:0.027	Accuracy:0.7000
# 현대리바트
# 	 RMSE:0.026	Accuracy:0.6643
# 현대모비스
# 	 RMSE:0.024	Accuracy:0.6667
# 현대미포조선
# 	 RMSE:0.032	Accuracy:0.6667
# 현대백화점
# 	 RMSE:0.022	Accuracy:0.7143
# 현대엘리베이
# 	 RMSE:0.047	Accuracy:0.6905
# 현대위아
# 	 RMSE:0.024	Accuracy:0.6612
# 현대제철
# 	 RMSE:0.028	Accuracy:0.6857
# 현대중공업
# 	 RMSE:0.042	Accuracy:0.6723
# 현대차
# 	 RMSE:0.022	Accuracy:0.6643
# 현대해상
# 	 RMSE:0.025	Accuracy:0.6286
# 현대홈쇼핑
# 	 RMSE:0.019	Accuracy:0.7091
# 호텔신라
# 	 RMSE:0.031	Accuracy:0.7143
# 효성
# 	 RMSE:0.045	Accuracy:0.6667
# 후성
# 	 RMSE:0.035	Accuracy:0.6381
# 휴켐스
# 	 RMSE:0.023	Accuracy:0.6905

# %%
rmse = [data[0] for key, data in result.items()]
acc = [data[1] for key, data in result.items()]

# %%
np.mean(acc), np.mean(rmse)
# Out:
# (0.6828916471134744, 0.02739634479307259)

# %%
min(acc), max(acc)
# Out:
# (0.5452380952380952, 0.75)

# %%
plt.plot(sorted(acc))
